# %%
pip install python-docx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.3/244.3 kB 3.5 MB/s eta 0:00:00
# ...

# %%
from docx import Document

# Load the document
doc = Document('/content/sample-docx-files-sample4.docx')

# Iterate through paragraphs and print text
for para in doc.paragraphs:
    print(para.text)
# Out:
# Video provides a powerful way to help you prove your point. When you click Online Video, you can paste in the embed code for the video you want to add. You can also type a keyword to search online for the video that best fits your document. To make your document look professionally produced, Word provides header, footer, cover page, and text box designs that complement each other. For example, you can add a matching cover page, header, and sidebar. Click Insert and then choose the elements you want from the different galleries. Themes and styles also help keep your document coordinated. When you click Design and choose a new Theme, the pictures, charts, and SmartArt graphics change to match your new theme. When you apply styles, your headings change to match the new theme. Save time in Word with new buttons that show up where you need them.
#
# ...

# %%
def process_docx(file_path):
  word_count = 0
  words = []

  for para in doc.paragraphs:
      for word in para.text.split():
          words.append(word)
          word_count += 1
          if word_count >= 500:
              break
      if word_count >= 500:
          break

  print(" ".join(words))

# %%
import re

text = " ".join(para.text for para in doc.paragraphs)

word_pattern = re.compile(r'\b[Bb]\w*\b')

words = word_pattern.findall(text)

words = words[:500]

print(" ".join(words))
# Out:
# best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best box buttons button before best b
# ...

# %%
# !pip install python-pptx
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 472.8/472.8 kB 5.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.1/165.1 kB 16.8 MB/s eta 0:00:00
# ...

# %%
def process_pptx(file_path):

  from pptx import Presentation
  prs = Presentation(file_path)

  for slide in prs.slides:
    for shape in slide.shapes:
      if hasattr(shape, "text"):
        text=shape.text
        print(text)
    print("....................")

# %%
def process_html(file_path):

  from bs4 import BeautifulSoup

  with open(file_path, 'r') as f:
      html_content = f.read()

  soup = BeautifulSoup(html_content, 'html.parser')

  soup.prettify()

# %%
def process_file(file_path):
    # Get the file extension
    file_extension = os.path.splitext(file_path)[1].lower()

    # Call the appropriate function based on the file extension
    if file_extension == '.pptx':
        process_pptx(file_path)
    elif file_extension == '.docx':
        process_docx(file_path)
    elif file_extension == '.html':
        process_html(file_path)
    else:
        print("Unsupported file type:", file_extension)


process_file('/content/sample-docx-files-sample4.docx')
# Out:
# Video provides a powerful way to help you prove your point. When you click Online Video, you can paste in the embed code for the video you want to add. You can also type a keyword to search online for the video that best fits your document. To make your document look professionally produced, Word provides header, footer, cover page, and text box designs that complement each other. For example, you can add a matching cover page, header, and sidebar. Click Insert and then choose the elements you want from the different galleries. Themes and styles also help keep your document coordinated. When you click Design and choose a new Theme, the pictures, charts, and SmartArt graphics change to match your new theme. When you apply styles, your headings change to match the new theme. Save time in Word with new buttons that show up where you need them. To change the way a picture fits in your document, click it and a button for layout options appears next to it. When you work on a table, click w
# ...

# %%
process_file('/content/IMDb Top 250 Movies.html')

# %%
process_file('/content/Free_Test_Data_100KB_PPTX.pptx')
# Out:
# FREE TEST DATA
# PPT FILE
# ....................
#
# FREE TEST DATA
#
# Lorem ipsum dolor sit amet, consectetur adipiscing elit. Donec iaculis elit nec ante eleifend, eget cursus tortor auctor. Integer at ultrices lorem, eget bibendum turpis. Praesent lacus sapien, ullamcorper.
#
#
#
#
# FTD
# FREE TEST DATA
# 2
#
#
# ....................
#
#
# Chart
#
# FTD
# FREE TEST DATA
# 3
# ....................
#
# Table
#
# FTD
# FREE TEST DATA
# 4
# ....................
#
#
#
# FTD
# FREE TEST DATA
# 5
# ....................

# %%
import json
def convertJson(type,content,path):
  return{
      "file_type":type,
      "content":content,
      "metadata": {
          "author":"123123",
          "data":1,
          "path":path
      }
  }

# %%
convertJson("pdf",content,/content/test.pdf)
# Out:
#   File "<ipython-input-58-dfab3d999542>", line 1
#     convertJson("pdf",content,/content/test.pdf)
#                               ^
# SyntaxError: invalid syntax

# %%
from transformers import pipeline
qa_pipeline = pipeline("question-answering")

def answer_question(context, question):
    result = qa_pipeline(question=question, context=context)
    return answer['answer']
